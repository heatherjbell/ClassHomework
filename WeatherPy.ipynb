# %%
# Out:
#   File "<ipython-input-1-499d69a12bf8>", line 2
#     pip install citipy
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from citipy import citipy
import numpy as np
from pprint import pprint
#from config import api_key (i will manually insert this)
#from config import gkey (i will manually insert this)
import matplotlib.pyplot as plt
import random
import time
import json
import requests
import datetime as dt

# %%
#keys
api_key = "ddcf7deb3091570bd28a1a5e0c780133"
gkey = 'AIzaSyD184p-HemrgaYcbyuqSlCPzmN3y5H9gkY'

# %%
#latitudes = np.random.uniform(-90, 90, size = 2000) #500 random numbers from -90 to 90 deg latitude
#longitudes = np.random.uniform(-180, 180, size = 2000) #500 random numbers from -180 to 180 deg longitude
#coordinates = list(zip(latitudes, longitudes))

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
url = "http://api.openweathermap.org/data/2.5/weather?"

city_sets = []
weather_list = []

for x in range(1,15):
    city_set = random.sample(cities, 50)
    city_sets.append(city_set)

print("City Data")
print("---------")    

weather_list = []
    
for city in cities:
        if len(weather_list) == 1000:
            print("End of Data Retrieval")
            break
        try:
            print(f"Gathering information: number {cities.index(city) + 1} for {city}.")

            city_url = url + "appid=" + api_key + "&q=" + city
            response = requests.get(city_url)
            city_weather = response.json()    

            weather_list.append({
                "City": city_weather['name'],
                "Country": city_weather['sys']['country'],
                "Temperature": (city_weather['main']['temp'] - 273.15),
                "Humidity": city_weather['main']['humidity'],
                "Cloudiness": city_weather['clouds']['all'],
                "Max Temp": (city_weather['main']['temp_max'] - 273.15),
                "Wind Speed": city_weather['wind']['speed'],
                "Latitude": city_weather['coord']['lat'],
                "Longitude": city_weather['coord']['lon'],
                "Date": time.ctime(city_weather['dt'])
            })
        except KeyError:
            print("No information for this city.")
# Out:
# City Data
# ---------
# Gathering information: number 1 for fortuna.
# Gathering information: number 2 for swedru.
# Gathering information: number 3 for georgetown.
# Gathering information: number 4 for rikitea.
# Gathering information: number 5 for norman wells.
# Gathering information: number 6 for guerrero negro.
# Gathering information: number 7 for punta arenas.
# Gathering information: number 8 for kauhajoki.
# Gathering information: number 9 for chabahar.
# Gathering information: number 10 for cape town.
# Gathering information: number 11 for castro.
# Gathering information: number 12 for bredasdorp.
# Gathering information: number 13 for kodiak.
# Gathering information: number 14 for tambun.
# Gathering information: number 15 for taksimo.
# Gathering information: number 16 for taolanaro.
# No information for this city.
# Gathering information: number 17 for butaritari.
# Gathering information: number 18 for one hundred mile house.
# No information for this city.
# ...

# %%
# save the dataframe as a csv
weather_df = pd.DataFrame(weather_list)
weather_df['Temperature (F)'] = (weather_df['Temperature'] * (9/5)) + 32
weather_df['Max Temp (F)'] = (weather_df['Max Temp'] * (9/5)) + 32
weather_df.to_csv('cityweather.csv')

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Max Temp (F)', figsize=(15,10), s=10)
plt.xlim(-85, 85)
plt.ylim(0, 120)
plt.title('Latitude vs. Temperature (F) | July 13, 2019')
plt.ylabel('Temperature (F)')
plt.savefig('LatitudeTemperature.png')

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Humidity', figsize=(15,10))
plt.xlim(-85, 85)
plt.ylim(-10, 120)
plt.title('Latitude vs. Humidity | Friday, July 13')
plt.ylabel('Humidity (%)')
plt.savefig('LatitudeHumidity.png')

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Cloudiness', figsize=(15,10))
plt.xlim(-85, 85)
plt.ylim(-10, 120)
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs. Cloudiness | Friday, July 13')
plt.savefig('LatitudeCloudiness.png')

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Wind Speed', figsize=(15,10))
plt.xlim(-85, 85)
plt.ylim(-1, 20)
plt.title('Wind Speed vs. Latitude | Friday, July 13')
plt.ylabel('Wind Speed (MPH)')
plt.savefig('LatitudeWind.png')

# %% [markdown]
# OBSERVATIONS:
#     - the closer you are to the equator, the hotter the temperature seems to be.
#     - the wind speeds seem faster further away from the equator.
#     - humidity seemingly increases further from the equator.
#     - cloud coverage seems relatively equal across distances.
